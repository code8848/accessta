# %%
print('h')
# Out:
# h

# %%
import pandas as pd
import os
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
#import seaborn as sns
import osmnx as ox
import pyotp
import requests

# %%
print('hi')
# Out:
# hi

# %%
address="Austin,Texas"
# dist= retain only those nodes within this many meters of the center of the graph, default is 
# the center of the address is the center of the graph
Austin_graph=ox.graph.graph_from_address(address, dist=20000, dist_type='bbox', network_type='bike', simplify=True, retain_all=False, truncate_by_edge=False, return_coords=False, clean_periphery=True, custom_filter=None) # I am using 'bike' as type of network as I includes all infractures that are used for walking (sidewalks..) as well as cycling (trails..). It also include residential roads used for biking.

# %%
ox.plot_graph(Austin_graph)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
ox.save_graph_xml(Austin_graph,'Data/OTP/austin20k.osm')
# Out:
# C:\Users\P-Koirala\AppData\Local\miniconda3\envs\OSM_miniconda\lib\site-packages\osmnx\osm_xml.py:187: UserWarning: In order for save_graph_xml to behave properly the graph must have been created with the `all_oneway` setting set to True.
#   warnings.warn(msg)

# %%
https://indicatrix.org/post/accessibility-analysis-with-python-and-opentripplanner/
https://gist.github.com/mattwigway/15c2d7dc64901f0f3cc5

# %%
# !pip opentripplanner
# Out:
# ERROR: unknown command "opentripplanner"

# %%
from opentripplanner import RoutingRequest, Graph
from opentripplanner.batch import BatchProcessor, PointSet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from opentripplanner import RoutingRequest, Graph
#       2 from opentripplanner.batch import BatchProcessor, PointSet
#
# ModuleNotFoundError: No module named 'opentripplanner'

# %%
import pyotp
from pyotp import OTP
`
otp = OTP('http://localhost:8080/otp/routers/default')
origin = (51.5244, -0.1278)
threshold = 1800 # 30 minutes
isochrone = otp.get_isochrone(origin, threshold, mode='TRANSIT,WALK', date='2022-03-16', time='08:00:00')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 7
#       5 origin = (51.5244, -0.1278)
#       6 threshold = 1800 # 30 minutes
# ----> 7 isochrone = otp.get_isochrone(origin, threshold, mode='TRANSIT,WALK', date='2022-03-16', time='08:00:00')
#
# AttributeError: 'OTP' object has no attribute 'get_isochrone'

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(*zip(*isochrone), color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       1 payload = {
#       2     'fromPlace': '30.295134, -97.732366',
#       3     'toPlace': '30.311869, -97.745267',
#       4
#       5     'mode': 'WALK'
#       6 }
#       8 #headers = {'Authorization': 'Bearer {}'.format(otp.now())}
# ---> 10 response = requests.get(otp_url, headers=headers, params=payload)
#
# NameError: name 'headers' is not defined
